# %% [markdown]
# # game7
# A last ditch effort to see if I can do some strange architecture that basically manually works through timeseries prediction with the three-to-one context.
#
# - **DONE:** Implemented going from t0,t1,t2 -> t3,t4,t5
# - **DONE:** Checked functionality for training, validation, and test
# - **DONE:** Implement all the way
#
# ### PERFORMANCE
# game7-001
# EPOCHS = 1, BATCH_SIZE = 1
#
# - **val:** loss = 0.16548786, mse_0 = 0.004235531, mse_1 = 0.010104967, mse_2 = 0.0122702215, mse_3 = 0.01302251, mse_4 = 0.012412912, mse_5 = 0.011608472, mse_6 = 0.011144915, mse_7 = 0.010888862, mse_8 = 0.010791112, mse_9 = 0.010776621, mse_10 = 0.010957689, mse_11 = 0.011275849, mse_12 = 0.0116046835, mse_13 = 0.011971064, mse_14 = 0.012422484
# - **test:** loss = 0.122545436, mse_0 = 0.0027932466, mse_1 = 0.006411494, mse_2 = 0.007906955, mse_3 = 0.008380044, mse_4 = 0.00849694, mse_5 = 0.00825126, mse_6 = 0.008125616, mse_7 = 0.008183181, mse_8 = 0.008291747, mse_9 = 0.0084821135, mse_10 = 0.00873525, mse_11 = 0.009053136, mse_12 = 0.009429835, mse_13 = 0.00980869, mse_14 = 0.010195843
#
# game7-002 - I forgot to shuffle data
#
# game7-003 - starting at 3:30am, finished at 6am
# EPOCHS = 32, BATCH_SIZE = 2
#
# - **val:** loss = 0.06358669, mse_0 = 0.0012782747, mse_1 = 0.0025433903, mse_2 = 0.0030069693, mse_3 = 0.0031504119, mse_4 = 0.0032255875, mse_5 = 0.0033676398, mse_6 = 0.0035771285, mse_7 = 0.0038843087, mse_8 = 0.004248825, mse_9 = 0.004635306, mse_10 = 0.0050595817, mse_11 = 0.0055486807, mse_12 = 0.006062766, mse_13 = 0.00667745, mse_14 = 0.0073203673
# - **test:** loss = 0.06958303, mse_0 = 0.0011164262, mse_1 = 0.0026532158, mse_2 = 0.0035117613, mse_3 = 0.0038644904, mse_4 = 0.004357377, mse_5 = 0.0044679, mse_6 = 0.0045076325, mse_7 = 0.0046599237, mse_8 = 0.0048659607, mse_9 = 0.005116142, mse_10 = 0.0053789, mse_11 = 0.0056886985, mse_12 = 0.0060561476, mse_13 = 0.0064551667, mse_14 = 0.0068832543
#
# Trying five-to-one context.
#
# game7-003-fivetoone - starting at 9:24am, finished at 11:45am
# EPOCHS = 32, BATCH_SIZE = 2, loss_weights: 12,8,8,6,6,4,4,2,2,1,1,1,1
#
# - **val:** loss = 0.1640802, mse_0 = 0.0006408061, mse_1 = 0.0010652168, mse_2 = 0.0014739773, mse_3 = 0.0019092818, mse_4 = 0.0024678463, mse_5 = 0.0032025508, mse_6 = 0.004182694, mse_7 = 0.005458644, mse_8 = 0.007158339, mse_9 = 0.00935544, mse_10 = 0.012058812, mse_11 = 0.015153308, mse_12 = 0.018471712
# - **test:** loss = 0.17469843, mse_0 = 0.0007959034, mse_1 = 0.0014077827, mse_2 = 0.0023067503, mse_3 = 0.002715021, mse_4 = 0.0031118034, mse_5 = 0.0036199992, mse_6 = 0.004272746, mse_7 = 0.005143355, mse_8 = 0.0063286866, mse_9 = 0.0079708295, mse_10 = 0.010086605, mse_11 = 0.012601355, mse_12 = 0.015296504
# - Loss being higher is expected because of weighting!
#
# game7-004-three-adaproon
# EPOCHS = 32, BATCH_SIZE = 2, loss_weights: 16,8,8,8,6,6,6,4,4,4,2,2,2,1,1,1,1, change lr_decay: 0.96 -> 0.99
#
# - **val:** loss = 0.36469963, mse_0 = 0.0013275808, mse_1 = 0.0026834363, mse_2 = 0.0034433375, mse_3 = 0.003981526, mse_4 = 0.004728066, mse_5 = 0.0060215704, mse_6 = 0.0077415165, mse_7 = 0.009770885, mse_8 = 0.011894595, mse_9 = 0.01415845, mse_10 = 0.016627902, mse_11 = 0.019854901, mse_12 = 0.023178255, mse_13 = 0.026466338, mse_14 = 0.029551003
# - **test:** loss = 0.31124339, mse_0 = 0.0011369614, mse_1 = 0.0026717351, mse_2 = 0.00350337, mse_3 = 0.0037981537, mse_4 = 0.004445305, mse_5 = 0.0051131384, mse_6 = 0.00619341, mse_7 = 0.007659987, mse_8 = 0.009200413, mse_9 = 0.011008872, mse_10 = 0.013130834, mse_11 = 0.01596948, mse_12 = 0.019023044, mse_13 = 0.021910315, mse_14 = 0.024486285
#
# game7-005-noreuse (not adaproon!!) - starting at 2:50pm
# EPOCHS = 32, BATCH_SIZE = 2, loss_weights: 16,8,8,8,6,6,6,4,4,4,2,2,2,1,1,1,1, lr_decay: still 0.99
#
# - **val:** loss = 0.18492533, mse_0 = 0.0014481391, mse_1 = 0.002602851, mse_2 = 0.002990409, mse_3 = 0.0031703636, mse_4 = 0.003427714, mse_5 = 0.003719338, mse_6 = 0.0038072444, mse_7 = 0.004018301, mse_8 = 0.0041832123, mse_9 = 0.004485013, mse_10 = 0.0043706526, mse_11 = 0.0044317497, mse_12 = 0.004520035, mse_13 = 0.004621852, mse_14 = 0.004511576
# - **test:** loss = 0.23296185, mse_0 = 0.0012816231, mse_1 = 0.0028932646, mse_2 = 0.0038005079, mse_3 = 0.0042540366, mse_4 = 0.0049026725, mse_5 = 0.0053134034, mse_6 = 0.005304159, mse_7 = 0.0055269697, mse_8 = 0.0056140358, mse_9 = 0.005865432, mse_10 = 0.0057099992, mse_11 = 0.005724207, mse_12 = 0.00580731, mse_13 = 0.005878767, mse_14 = 0.005659235
#
# ### TO-DO
# - **DONE:** made adaproon data
# - **DONE:** Finish training five-to-one
# - **DONE:** Eval five-to-one
# - **DONE:** Test five-to-one
# - Remove 1 GPU
# - **DONE:** Try a quick epoch of NOT reusing!?
# - **DONE:** Train three-to-one on adaproon
# - **DONE:** Eval three-to-one on adaproon
# - **DONE:** Test three-to-one on adaproon
# - If slice prune adjustment was better but still not great, train four-to-one
# - Eval four-to-one
# - Test four-to-one

# %%
import os
import numpy as np
import tensorflow as wtf
import tensorflow.contrib.rnn as rnn
import data_utils as du
# Out:
# /home/noodles/.conda/envs/turntable/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /home/noodles/.conda/envs/turntable/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %%
EPOCHS = 32

num_train, num_val, num_test = 70, 10, 20
train_data,val_data,test_data = du.create_dicts(num_train, num_val, num_test)

# %%
# du.what_tf_g7('val', val_data)
# du.what_tf_g7('test', test_data)
# du.what_tf_g7('train', train_data)

# %%
MODEL_TYPE = 'game7'
OVERFIT = False

MODEL_NAME = MODEL_TYPE + '-005-noreuse'

BATCH_SIZE = 2

# %%
def encoder_fn(inputs):
    conv1_1 = wtf.layers.conv2d(inputs,
                                filters=64,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv1_1',
                                reuse=wtf.AUTO_REUSE)
    conv1_2 = wtf.layers.conv2d(conv1_1,
                                filters=64,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv1_2',
                                reuse=wtf.AUTO_REUSE)
    pool1 = wtf.layers.max_pooling2d(conv1_2,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool1')
        
    conv2_1 = wtf.layers.conv2d(pool1,
                                filters=128,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv2_1',
                                reuse=wtf.AUTO_REUSE)
    conv2_2 = wtf.layers.conv2d(conv2_1,
                                filters=128,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv2_2',
                                reuse=wtf.AUTO_REUSE)
    pool2 = wtf.layers.max_pooling2d(conv2_2,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool2')
        
    conv3_1 = wtf.layers.conv2d(pool2,
                                filters=256,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv3_1',
                                reuse=wtf.AUTO_REUSE)
    conv3_2 = wtf.layers.conv2d(conv3_1,
                                filters=256,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv3_2',
                                reuse=wtf.AUTO_REUSE)
    conv3_3 = wtf.layers.conv2d(conv3_2,
                                filters=256,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv3_3',
                                reuse=wtf.AUTO_REUSE)
    pool3 = wtf.layers.max_pooling2d(conv3_3,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool3')
        
    conv4_1 = wtf.layers.conv2d(pool3,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv4_1',
                                reuse=wtf.AUTO_REUSE)
    conv4_2 = wtf.layers.conv2d(conv4_1,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv4_2',
                                reuse=wtf.AUTO_REUSE)
    conv4_3 = wtf.layers.conv2d(conv4_2,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv4_3',
                                reuse=wtf.AUTO_REUSE)
    pool4 = wtf.layers.max_pooling2d(conv4_3,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool4')
    
    conv5_1 = wtf.layers.conv2d(pool4,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv5_1',
                                reuse=wtf.AUTO_REUSE)
    conv5_2 = wtf.layers.conv2d(conv5_1,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv5_2',
                                reuse=wtf.AUTO_REUSE)
    conv5_3 = wtf.layers.conv2d(conv5_2,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv5_3',
                                reuse=wtf.AUTO_REUSE)
    pool5 = wtf.layers.max_pooling2d(conv5_3,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool5')
    
    conv6_1 = wtf.layers.conv2d(pool5,
                                filters=1,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv6_1',
                                reuse=wtf.AUTO_REUSE)
        
    dout = wtf.layers.dropout(conv6_1,
                              rate=0.0)
    
    outputs = dout
    return outputs, pool1, pool3, pool4

# %%
def encoder_fn(inputs, vscope):
    with wtf.variable_scope(vscope):
        conv1_1 = wtf.layers.conv2d(inputs,
                                filters=64,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv1_1',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        conv1_2 = wtf.layers.conv2d(conv1_1,
                                filters=64,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv1_2',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        pool1 = wtf.layers.max_pooling2d(conv1_2,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool1')
        
        conv2_1 = wtf.layers.conv2d(pool1,
                                filters=128,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv2_1',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        conv2_2 = wtf.layers.conv2d(conv2_1,
                                filters=128,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv2_2',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        pool2 = wtf.layers.max_pooling2d(conv2_2,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool2')
        
        conv3_1 = wtf.layers.conv2d(pool2,
                                filters=256,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv3_1',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        conv3_2 = wtf.layers.conv2d(conv3_1,
                                filters=256,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv3_2',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        conv3_3 = wtf.layers.conv2d(conv3_2,
                                filters=256,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv3_3',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        pool3 = wtf.layers.max_pooling2d(conv3_3,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool3')
        
        conv4_1 = wtf.layers.conv2d(pool3,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv4_1',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        conv4_2 = wtf.layers.conv2d(conv4_1,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv4_2',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        conv4_3 = wtf.layers.conv2d(conv4_2,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv4_3',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        pool4 = wtf.layers.max_pooling2d(conv4_3,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool4')
    
        conv5_1 = wtf.layers.conv2d(pool4,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv5_1',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        conv5_2 = wtf.layers.conv2d(conv5_1,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv5_2',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        conv5_3 = wtf.layers.conv2d(conv5_2,
                                filters=512,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv5_3',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        pool5 = wtf.layers.max_pooling2d(conv5_3,
                                     pool_size=2,
                                     strides=2,
                                     padding='same',
                                     name='pool5')
    
        conv6_1 = wtf.layers.conv2d(pool5,
                                filters=1,
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                activation=wtf.nn.relu,
                                kernel_initializer=wtf.variance_scaling_initializer(scale=2.0),
                                name='conv6_1',
#                                 reuse=wtf.AUTO_REUSE,
                                reuse=False)
        
        dout = wtf.layers.dropout(conv6_1,
                              rate=0.0)
    
        outputs = dout
        return outputs, pool1, pool3, pool4

# %%
def decoder_fn(inputs, pool1, pool3, pool4):
    deconv1 = wtf.layers.conv2d_transpose(inputs,
                                          filters=pool4.get_shape().as_list()[-1],
                                          kernel_size=4,
                                          strides=2,
                                          padding='same',
                                          reuse=False)
    deconv1_skip = wtf.add(deconv1, pool4)
    
    deconv2 = wtf.layers.conv2d_transpose(deconv1_skip,
                                          filters=pool3.get_shape().as_list()[-1],
                                          kernel_size=4,
                                          strides=2,
                                          padding='same',
                                          reuse=False)
    deconv2_skip = wtf.add(deconv2, pool3)
    
    deconv3 = wtf.layers.conv2d_transpose(deconv2_skip,
                                          filters=1,
                                          kernel_size=16,
                                          strides=8,
                                          padding='same',
                                          reuse=False)
#     deconv3_skip = wtf.add(deconv3, pool1)
    
    outputs = deconv3
    return outputs

# %%
# t0,t1,t2 -> t3 + LSTM

def model_fn(features,
             labels, # (N,3,H,W,1)
             mode,
             params):
    with wtf.device('/device:GPU:1'):
        labels = wtf.transpose(labels, [0, 2, 3, 1, 4])
        labels = wtf.squeeze(labels, [4]) # (N,H,W,3)
        
        # t0, t1, t2  -> t3
        inputs_N3HW1 = features
        print(inputs_N3HW1)
        inputs_NHW3 = wtf.transpose(inputs_N3HW1, [0, 2, 3, 1, 4]) # (N,H,W,3,1)
        inp0 = wtf.squeeze(inputs_NHW3, [4]) # (N,H,W,3)
        print(inp0)
        enc0, pool0_1, pool0_3, pool0_4 = encoder_fn(inp0) # enc0 (N,6,7,1)
        print(enc0)
        dec0 = decoder_fn(enc0, pool0_1, pool0_3, pool0_4) # dec0 (N,H,W,1)
        print(dec0) # t3
        
        # t1, t2, t3  -> t4
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp1 = wtf.concat([wtf.expand_dims(inp0[:,:,:,1], -1),
                               wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp1 = wtf.concat([wtf.expand_dims(inp0[:,:,:,1], -1),
                               wtf.expand_dims(inp0[:,:,:,2], -1),
                               dec0], axis=3)
        print(inp1)
        enc1, pool1_1, pool1_3, pool1_4 = encoder_fn(inp1) # enc1 (N,6,7,1)
        print(enc1)
        dec1 = decoder_fn(enc1, pool1_1, pool1_3, pool1_4) # dec1 (N,H,W,1)
        print(dec1) # t4
        
        # t2, t3, t4  -> t5
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp2 = wtf.concat([wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp2 = wtf.concat([wtf.expand_dims(inp0[:,:,:,2], -1),
                               dec0,
                               dec1], axis=3)
        print(inp2)
        enc2, pool2_1, pool2_3, pool2_4 = encoder_fn(inp2) # enc2 (N,6,7,1)
        print(enc2)
        dec2 = decoder_fn(enc2, pool2_1, pool2_3, pool2_4) # dec2 (N,H,W,1)
        print(dec2) # t5
        
        # t3, t4, t5  -> t6
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp3 = wtf.concat([wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp3 = wtf.concat([dec0,
                               dec1,
                               dec2], axis=3)
        enc3, pool3_1, pool3_3, pool3_4 = encoder_fn(inp3) # enc3 (N,6,7,1)
        dec3 = decoder_fn(enc3, pool3_1, pool3_3, pool3_4) # dec3 (N,H,W,1)
        
        # t4, t5, t6  -> t7
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp4 = wtf.concat([wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp4 = wtf.concat([dec1,
                               dec2,
                               dec3], axis=3)
        enc4, pool4_1, pool4_3, pool4_4 = encoder_fn(inp4)
        dec4 = decoder_fn(enc4, pool4_1, pool4_3, pool4_4)
        
        # t5, t6, t7  -> t8
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp5 = wtf.concat([wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp5 = wtf.concat([dec2,
                               dec3,
                               dec4], axis=3)
        enc5, pool5_1, pool5_3, pool5_4 = encoder_fn(inp5)
        dec5 = decoder_fn(enc5, pool5_1, pool5_3, pool5_4)
        
        # t6, t7, t8  -> t9
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp6 = wtf.concat([wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp6 = wtf.concat([dec3,
                               dec4,
                               dec5], axis=3)
        enc6, pool6_1, pool6_3, pool6_4 = encoder_fn(inp6)
        dec6 = decoder_fn(enc6, pool6_1, pool6_3, pool6_4)
        
        # t7, t8, t9  -> t10
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp7 = wtf.concat([wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp7 = wtf.concat([dec4,
                               dec5,
                               dec6], axis=3)
        enc7, pool7_1, pool7_3, pool7_4 = encoder_fn(inp7)
        dec7 = decoder_fn(enc7, pool7_1, pool7_3, pool7_4)
        
        # t8, t9, t10 -> t11
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp8 = wtf.concat([wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1),
                               wtf.expand_dims(labels[:,:,:,7], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp8 = wtf.concat([dec5,
                               dec6,
                               dec7], axis=3)
        enc8, pool8_1, pool8_3, pool8_4 = encoder_fn(inp8)
        dec8 = decoder_fn(enc8, pool8_1, pool8_3, pool8_4)
        
        # t9, t10,t11 -> t12
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp9 = wtf.concat([wtf.expand_dims(labels[:,:,:,6], -1),
                               wtf.expand_dims(labels[:,:,:,7], -1),
                               wtf.expand_dims(labels[:,:,:,8], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp9 = wtf.concat([dec6,
                               dec7,
                               dec8], axis=3)
        enc9, pool9_1, pool9_3, pool9_4 = encoder_fn(inp9)
        dec9 = decoder_fn(enc9, pool9_1, pool9_3, pool9_4)
        
        # t10,t11,t12 -> t13
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp10 = wtf.concat([wtf.expand_dims(labels[:,:,:,7], -1),
                                wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp10 = wtf.concat([dec7,
                                dec8,
                                dec9], axis=3)
        enc10, pool10_1, pool10_3, pool10_4 = encoder_fn(inp10)
        dec10 = decoder_fn(enc10, pool10_1, pool10_3, pool10_4)
        
        # t11,t12,t13 -> t14
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp11 = wtf.concat([wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1),
                                wtf.expand_dims(labels[:,:,:,10], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp11 = wtf.concat([dec8,
                                dec9,
                                dec10], axis=3)
        enc11, pool11_1, pool11_3, pool11_4 = encoder_fn(inp11)
        dec11 = decoder_fn(enc11, pool11_1, pool11_3, pool11_4)
        
        # t12,t13,t14 -> t15
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp12 = wtf.concat([wtf.expand_dims(labels[:,:,:,9], -1),
                                wtf.expand_dims(labels[:,:,:,10], -1),
                                wtf.expand_dims(labels[:,:,:,11], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp12 = wtf.concat([dec9,
                                dec10,
                                dec11], axis=3)
        enc12, pool12_1, pool12_3, pool12_4 = encoder_fn(inp12)
        dec12 = decoder_fn(enc12, pool12_1, pool12_3, pool12_4)
        
        # t13,t14,t15 -> t16
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp13 = wtf.concat([wtf.expand_dims(labels[:,:,:,10], -1),
                                wtf.expand_dims(labels[:,:,:,11], -1),
                                wtf.expand_dims(labels[:,:,:,12], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp13 = wtf.concat([dec10,
                                dec11,
                                dec12], axis=3)
        enc13, pool13_1, pool13_3, pool13_4 = encoder_fn(inp13)
        dec13 = decoder_fn(enc13, pool13_1, pool13_3, pool13_4)
        
        # t14,t15,t16 -> t17
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp14 = wtf.concat([wtf.expand_dims(labels[:,:,:,11], -1),
                                wtf.expand_dims(labels[:,:,:,12], -1),
                                wtf.expand_dims(labels[:,:,:,13], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp14 = wtf.concat([dec11,
                                dec12,
                                dec13], axis=3)
        enc14, pool14_1, pool14_3, pool14_4 = encoder_fn(inp14)
        dec14 = decoder_fn(enc14, pool14_1, pool14_3, pool14_4)
        
        # Adds concatenated inputs and outputs to be displayed in TensorBoard
        disp00 = wtf.concat([wtf.expand_dims(inp0[:,:,:,0], -1),
                             wtf.expand_dims(inp0[:,:,:,1], -1),
                             wtf.expand_dims(inp0[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,0], -1),
                             dec0], axis=1)
        disp01 = wtf.concat([wtf.expand_dims(inp1[:,:,:,0], -1),
                             wtf.expand_dims(inp1[:,:,:,1], -1),
                             wtf.expand_dims(inp1[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,1], -1),
                             dec1], axis=1)
        disp02 = wtf.concat([wtf.expand_dims(inp2[:,:,:,0], -1),
                             wtf.expand_dims(inp2[:,:,:,1], -1),
                             wtf.expand_dims(inp2[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,2], -1),
                             dec2], axis=1)
        disp03 = wtf.concat([wtf.expand_dims(inp3[:,:,:,0], -1),
                             wtf.expand_dims(inp3[:,:,:,1], -1),
                             wtf.expand_dims(inp3[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,3], -1),
                             dec3], axis=1)
        disp04 = wtf.concat([wtf.expand_dims(inp4[:,:,:,0], -1),
                             wtf.expand_dims(inp4[:,:,:,1], -1),
                             wtf.expand_dims(inp4[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,4], -1),
                             dec4], axis=1)
        disp05 = wtf.concat([wtf.expand_dims(inp5[:,:,:,0], -1),
                             wtf.expand_dims(inp5[:,:,:,1], -1),
                             wtf.expand_dims(inp5[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,5], -1),
                             dec5], axis=1)
        disp06 = wtf.concat([wtf.expand_dims(inp6[:,:,:,0], -1),
                             wtf.expand_dims(inp6[:,:,:,1], -1),
                             wtf.expand_dims(inp6[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,6], -1),
                             dec6], axis=1)
        disp07 = wtf.concat([wtf.expand_dims(inp7[:,:,:,0], -1),
                             wtf.expand_dims(inp7[:,:,:,1], -1),
                             wtf.expand_dims(inp7[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,7], -1),
                             dec7], axis=1)
        disp08 = wtf.concat([wtf.expand_dims(inp8[:,:,:,0], -1),
                             wtf.expand_dims(inp8[:,:,:,1], -1),
                             wtf.expand_dims(inp8[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,8], -1),
                             dec8], axis=1)
        disp09 = wtf.concat([wtf.expand_dims(inp9[:,:,:,0], -1),
                             wtf.expand_dims(inp9[:,:,:,1], -1),
                             wtf.expand_dims(inp9[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,9], -1),
                             dec9], axis=1)
        disp10 = wtf.concat([wtf.expand_dims(inp10[:,:,:,0], -1),
                             wtf.expand_dims(inp10[:,:,:,1], -1),
                             wtf.expand_dims(inp10[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,10], -1),
                             dec10], axis=1)
        disp11 = wtf.concat([wtf.expand_dims(inp11[:,:,:,0], -1),
                             wtf.expand_dims(inp11[:,:,:,1], -1),
                             wtf.expand_dims(inp11[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,11], -1),
                             dec11], axis=1)
        disp12 = wtf.concat([wtf.expand_dims(inp12[:,:,:,0], -1),
                             wtf.expand_dims(inp12[:,:,:,1], -1),
                             wtf.expand_dims(inp12[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,12], -1),
                             dec12], axis=1)
        disp13 = wtf.concat([wtf.expand_dims(inp13[:,:,:,0], -1),
                             wtf.expand_dims(inp13[:,:,:,1], -1),
                             wtf.expand_dims(inp13[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,13], -1),
                             dec13], axis=1)
        disp14 = wtf.concat([wtf.expand_dims(inp14[:,:,:,0], -1),
                             wtf.expand_dims(inp14[:,:,:,1], -1),
                             wtf.expand_dims(inp14[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,14], -1),
                             dec14], axis=1)
        disp = wtf.concat([disp00, disp01, disp02, disp03, disp04,
                           disp05, disp06, disp07, disp08, disp09,
                           disp10, disp11, disp12, disp13, disp14], axis=2)
        wtf.summary.image('concat', disp, max_outputs=200)
        
        loss = wtf.reduce_sum(16*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,0], -1), dec0)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,1], -1), dec1)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,2], -1), dec2)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,3], -1), dec3)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,4], -1), dec4)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,5], -1), dec5)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,6], -1), dec6)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,7], -1), dec7)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,8], -1), dec8)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,9], -1), dec9)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,10], -1), dec10)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,11], -1), dec11)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,12], -1), dec12)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,13], -1), dec13)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,14], -1), dec14))
        
        outputs = dec14
        
        predictions = {'results': outputs}
    
        if mode == wtf.estimator.ModeKeys.PREDICT:
            export_outputs = {
                'predictions': wtf.estimator.export.PredictOutput(outputs)
            }
            return wtf.estimator.EstimatorSpec(
                mode=mode,
                predictions=outputs
            )
        
        global_step = wtf.train.get_global_step()
        lr = wtf.train.exponential_decay(params.learning_rate, global_step, 10000, 0.99, staircase=True)
        
        wtf.summary.scalar('learning_rate', lr)
#         wtf.summary.scalar('learning_rate', params.learning_rate)
        
        optimizer = wtf.train.AdamOptimizer(
#             learning_rate=params.learning_rate,
            learning_rate=lr,
            beta1=params.beta1,
            beta2=params.beta2
        )
    
        update_ops = wtf.get_collection(wtf.GraphKeys.UPDATE_OPS)
        with wtf.control_dependencies(update_ops):
            train_op = optimizer.minimize(
                loss=loss, global_step=wtf.train.get_global_step())
    
        eval_metric_ops = {
            "mse_0": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,0], -1), dec0),
            "mse_1": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,1], -1), dec1),
            "mse_2": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,2], -1), dec2),
            "mse_3": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,3], -1), dec3),
            "mse_4": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,4], -1), dec4),
            "mse_5": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,5], -1), dec5),
            "mse_6": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,6], -1), dec6),
            "mse_7": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,7], -1), dec7),
            "mse_8": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,8], -1), dec8),
            "mse_9": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,9], -1), dec9),
            "mse_10": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,10], -1), dec10),
            "mse_11": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,11], -1), dec11),
            "mse_12": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,12], -1), dec12),
            "mse_13": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,13], -1), dec13),
            "mse_14": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,14], -1), dec14)
        }
        
        eval_summary_hook = wtf.train.SummarySaverHook(
                                save_steps=1,
                                output_dir= "summary/train/" + MODEL_NAME + "/eval",
                                scaffold=wtf.train.Scaffold(summary_op=wtf.summary.merge_all()))
        
        evaluation_hooks=[]
        evaluation_hooks.append(eval_summary_hook)
    
        estimator_spec = wtf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss,
            train_op=train_op,
            eval_metric_ops=eval_metric_ops,
            evaluation_hooks=evaluation_hooks
        )
        
        return estimator_spec

# %%
# t0,t1,t2 -> t3 + LSTM
# NO REUSE

def model_fn(features,
             labels, # (N,3,H,W,1)
             mode,
             params):
    with wtf.device('/device:GPU:1'):
        labels = wtf.transpose(labels, [0, 2, 3, 1, 4])
        labels = wtf.squeeze(labels, [4]) # (N,H,W,3)
        
        # t0, t1, t2  -> t3
        inputs_N3HW1 = features
        print(inputs_N3HW1)
        inputs_NHW3 = wtf.transpose(inputs_N3HW1, [0, 2, 3, 1, 4]) # (N,H,W,3,1)
        inp0 = wtf.squeeze(inputs_NHW3, [4]) # (N,H,W,3)
        print(inp0)
        enc0, pool0_1, pool0_3, pool0_4 = encoder_fn(inp0, 'v00') # enc0 (N,6,7,1)
        print(enc0)
        dec0 = decoder_fn(enc0, pool0_1, pool0_3, pool0_4) # dec0 (N,H,W,1)
        print(dec0) # t3
        
        # t1, t2, t3  -> t4
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp1 = wtf.concat([wtf.expand_dims(inp0[:,:,:,1], -1),
                               wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp1 = wtf.concat([wtf.expand_dims(inp0[:,:,:,1], -1),
                               wtf.expand_dims(inp0[:,:,:,2], -1),
                               dec0], axis=3)
        print(inp1)
        enc1, pool1_1, pool1_3, pool1_4 = encoder_fn(inp1, 'v01') # enc1 (N,6,7,1)
        print(enc1)
        dec1 = decoder_fn(enc1, pool1_1, pool1_3, pool1_4) # dec1 (N,H,W,1)
        print(dec1) # t4
        
        # t2, t3, t4  -> t5
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp2 = wtf.concat([wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp2 = wtf.concat([wtf.expand_dims(inp0[:,:,:,2], -1),
                               dec0,
                               dec1], axis=3)
        print(inp2)
        enc2, pool2_1, pool2_3, pool2_4 = encoder_fn(inp2, 'v02') # enc2 (N,6,7,1)
        print(enc2)
        dec2 = decoder_fn(enc2, pool2_1, pool2_3, pool2_4) # dec2 (N,H,W,1)
        print(dec2) # t5
        
        # t3, t4, t5  -> t6
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp3 = wtf.concat([wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp3 = wtf.concat([dec0,
                               dec1,
                               dec2], axis=3)
        enc3, pool3_1, pool3_3, pool3_4 = encoder_fn(inp3, 'v03') # enc3 (N,6,7,1)
        dec3 = decoder_fn(enc3, pool3_1, pool3_3, pool3_4) # dec3 (N,H,W,1)
        
        # t4, t5, t6  -> t7
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp4 = wtf.concat([wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp4 = wtf.concat([dec1,
                               dec2,
                               dec3], axis=3)
        enc4, pool4_1, pool4_3, pool4_4 = encoder_fn(inp4, 'v04')
        dec4 = decoder_fn(enc4, pool4_1, pool4_3, pool4_4)
        
        # t5, t6, t7  -> t8
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp5 = wtf.concat([wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp5 = wtf.concat([dec2,
                               dec3,
                               dec4], axis=3)
        enc5, pool5_1, pool5_3, pool5_4 = encoder_fn(inp5, 'v05')
        dec5 = decoder_fn(enc5, pool5_1, pool5_3, pool5_4)
        
        # t6, t7, t8  -> t9
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp6 = wtf.concat([wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp6 = wtf.concat([dec3,
                               dec4,
                               dec5], axis=3)
        enc6, pool6_1, pool6_3, pool6_4 = encoder_fn(inp6, 'v06')
        dec6 = decoder_fn(enc6, pool6_1, pool6_3, pool6_4)
        
        # t7, t8, t9  -> t10
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp7 = wtf.concat([wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp7 = wtf.concat([dec4,
                               dec5,
                               dec6], axis=3)
        enc7, pool7_1, pool7_3, pool7_4 = encoder_fn(inp7, 'v07')
        dec7 = decoder_fn(enc7, pool7_1, pool7_3, pool7_4)
        
        # t8, t9, t10 -> t11
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp8 = wtf.concat([wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1),
                               wtf.expand_dims(labels[:,:,:,7], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp8 = wtf.concat([dec5,
                               dec6,
                               dec7], axis=3)
        enc8, pool8_1, pool8_3, pool8_4 = encoder_fn(inp8, 'v08')
        dec8 = decoder_fn(enc8, pool8_1, pool8_3, pool8_4)
        
        # t9, t10,t11 -> t12
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp9 = wtf.concat([wtf.expand_dims(labels[:,:,:,6], -1),
                               wtf.expand_dims(labels[:,:,:,7], -1),
                               wtf.expand_dims(labels[:,:,:,8], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp9 = wtf.concat([dec6,
                               dec7,
                               dec8], axis=3)
        enc9, pool9_1, pool9_3, pool9_4 = encoder_fn(inp9, 'v09')
        dec9 = decoder_fn(enc9, pool9_1, pool9_3, pool9_4)
        
        # t10,t11,t12 -> t13
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp10 = wtf.concat([wtf.expand_dims(labels[:,:,:,7], -1),
                                wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp10 = wtf.concat([dec7,
                                dec8,
                                dec9], axis=3)
        enc10, pool10_1, pool10_3, pool10_4 = encoder_fn(inp10, 'v10')
        dec10 = decoder_fn(enc10, pool10_1, pool10_3, pool10_4)
        
        # t11,t12,t13 -> t14
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp11 = wtf.concat([wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1),
                                wtf.expand_dims(labels[:,:,:,10], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp11 = wtf.concat([dec8,
                                dec9,
                                dec10], axis=3)
        enc11, pool11_1, pool11_3, pool11_4 = encoder_fn(inp11, 'v11')
        dec11 = decoder_fn(enc11, pool11_1, pool11_3, pool11_4)
        
        # t12,t13,t14 -> t15
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp12 = wtf.concat([wtf.expand_dims(labels[:,:,:,9], -1),
                                wtf.expand_dims(labels[:,:,:,10], -1),
                                wtf.expand_dims(labels[:,:,:,11], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp12 = wtf.concat([dec9,
                                dec10,
                                dec11], axis=3)
        enc12, pool12_1, pool12_3, pool12_4 = encoder_fn(inp12, 'v12')
        dec12 = decoder_fn(enc12, pool12_1, pool12_3, pool12_4)
        
        # t13,t14,t15 -> t16
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp13 = wtf.concat([wtf.expand_dims(labels[:,:,:,10], -1),
                                wtf.expand_dims(labels[:,:,:,11], -1),
                                wtf.expand_dims(labels[:,:,:,12], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp13 = wtf.concat([dec10,
                                dec11,
                                dec12], axis=3)
        enc13, pool13_1, pool13_3, pool13_4 = encoder_fn(inp13, 'v13')
        dec13 = decoder_fn(enc13, pool13_1, pool13_3, pool13_4)
        
        # t14,t15,t16 -> t17
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp14 = wtf.concat([wtf.expand_dims(labels[:,:,:,11], -1),
                                wtf.expand_dims(labels[:,:,:,12], -1),
                                wtf.expand_dims(labels[:,:,:,13], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp14 = wtf.concat([dec11,
                                dec12,
                                dec13], axis=3)
        enc14, pool14_1, pool14_3, pool14_4 = encoder_fn(inp14, 'v14')
        dec14 = decoder_fn(enc14, pool14_1, pool14_3, pool14_4)
        
        # Adds concatenated inputs and outputs to be displayed in TensorBoard
        disp00 = wtf.concat([wtf.expand_dims(inp0[:,:,:,0], -1),
                             wtf.expand_dims(inp0[:,:,:,1], -1),
                             wtf.expand_dims(inp0[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,0], -1),
                             dec0], axis=1)
        disp01 = wtf.concat([wtf.expand_dims(inp1[:,:,:,0], -1),
                             wtf.expand_dims(inp1[:,:,:,1], -1),
                             wtf.expand_dims(inp1[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,1], -1),
                             dec1], axis=1)
        disp02 = wtf.concat([wtf.expand_dims(inp2[:,:,:,0], -1),
                             wtf.expand_dims(inp2[:,:,:,1], -1),
                             wtf.expand_dims(inp2[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,2], -1),
                             dec2], axis=1)
        disp03 = wtf.concat([wtf.expand_dims(inp3[:,:,:,0], -1),
                             wtf.expand_dims(inp3[:,:,:,1], -1),
                             wtf.expand_dims(inp3[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,3], -1),
                             dec3], axis=1)
        disp04 = wtf.concat([wtf.expand_dims(inp4[:,:,:,0], -1),
                             wtf.expand_dims(inp4[:,:,:,1], -1),
                             wtf.expand_dims(inp4[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,4], -1),
                             dec4], axis=1)
        disp05 = wtf.concat([wtf.expand_dims(inp5[:,:,:,0], -1),
                             wtf.expand_dims(inp5[:,:,:,1], -1),
                             wtf.expand_dims(inp5[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,5], -1),
                             dec5], axis=1)
        disp06 = wtf.concat([wtf.expand_dims(inp6[:,:,:,0], -1),
                             wtf.expand_dims(inp6[:,:,:,1], -1),
                             wtf.expand_dims(inp6[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,6], -1),
                             dec6], axis=1)
        disp07 = wtf.concat([wtf.expand_dims(inp7[:,:,:,0], -1),
                             wtf.expand_dims(inp7[:,:,:,1], -1),
                             wtf.expand_dims(inp7[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,7], -1),
                             dec7], axis=1)
        disp08 = wtf.concat([wtf.expand_dims(inp8[:,:,:,0], -1),
                             wtf.expand_dims(inp8[:,:,:,1], -1),
                             wtf.expand_dims(inp8[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,8], -1),
                             dec8], axis=1)
        disp09 = wtf.concat([wtf.expand_dims(inp9[:,:,:,0], -1),
                             wtf.expand_dims(inp9[:,:,:,1], -1),
                             wtf.expand_dims(inp9[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,9], -1),
                             dec9], axis=1)
        disp10 = wtf.concat([wtf.expand_dims(inp10[:,:,:,0], -1),
                             wtf.expand_dims(inp10[:,:,:,1], -1),
                             wtf.expand_dims(inp10[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,10], -1),
                             dec10], axis=1)
        disp11 = wtf.concat([wtf.expand_dims(inp11[:,:,:,0], -1),
                             wtf.expand_dims(inp11[:,:,:,1], -1),
                             wtf.expand_dims(inp11[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,11], -1),
                             dec11], axis=1)
        disp12 = wtf.concat([wtf.expand_dims(inp12[:,:,:,0], -1),
                             wtf.expand_dims(inp12[:,:,:,1], -1),
                             wtf.expand_dims(inp12[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,12], -1),
                             dec12], axis=1)
        disp13 = wtf.concat([wtf.expand_dims(inp13[:,:,:,0], -1),
                             wtf.expand_dims(inp13[:,:,:,1], -1),
                             wtf.expand_dims(inp13[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,13], -1),
                             dec13], axis=1)
        disp14 = wtf.concat([wtf.expand_dims(inp14[:,:,:,0], -1),
                             wtf.expand_dims(inp14[:,:,:,1], -1),
                             wtf.expand_dims(inp14[:,:,:,2], -1),
                             wtf.expand_dims(labels[:,:,:,14], -1),
                             dec14], axis=1)
        disp = wtf.concat([disp00, disp01, disp02, disp03, disp04,
                           disp05, disp06, disp07, disp08, disp09,
                           disp10, disp11, disp12, disp13, disp14], axis=2)
        wtf.summary.image('concat', disp, max_outputs=200)
        
        loss = wtf.reduce_sum(16*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,0], -1), dec0)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,1], -1), dec1)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,2], -1), dec2)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,3], -1), dec3)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,4], -1), dec4)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,5], -1), dec5)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,6], -1), dec6)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,7], -1), dec7)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,8], -1), dec8)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,9], -1), dec9)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,10], -1), dec10)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,11], -1), dec11)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,12], -1), dec12)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,13], -1), dec13)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,14], -1), dec14))
        
        outputs = dec14
        
        predictions = {'results': outputs}
    
        if mode == wtf.estimator.ModeKeys.PREDICT:
            export_outputs = {
                'predictions': wtf.estimator.export.PredictOutput(outputs)
            }
            return wtf.estimator.EstimatorSpec(
                mode=mode,
                predictions=outputs
            )
        
        global_step = wtf.train.get_global_step()
        lr = wtf.train.exponential_decay(params.learning_rate, global_step, 10000, 0.99, staircase=True)
        
        wtf.summary.scalar('learning_rate', lr)
#         wtf.summary.scalar('learning_rate', params.learning_rate)
        
        optimizer = wtf.train.AdamOptimizer(
#             learning_rate=params.learning_rate,
            learning_rate=lr,
            beta1=params.beta1,
            beta2=params.beta2
        )
    
        update_ops = wtf.get_collection(wtf.GraphKeys.UPDATE_OPS)
        with wtf.control_dependencies(update_ops):
            train_op = optimizer.minimize(
                loss=loss, global_step=wtf.train.get_global_step())
    
        eval_metric_ops = {
            "mse_0": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,0], -1), dec0),
            "mse_1": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,1], -1), dec1),
            "mse_2": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,2], -1), dec2),
            "mse_3": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,3], -1), dec3),
            "mse_4": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,4], -1), dec4),
            "mse_5": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,5], -1), dec5),
            "mse_6": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,6], -1), dec6),
            "mse_7": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,7], -1), dec7),
            "mse_8": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,8], -1), dec8),
            "mse_9": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,9], -1), dec9),
            "mse_10": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,10], -1), dec10),
            "mse_11": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,11], -1), dec11),
            "mse_12": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,12], -1), dec12),
            "mse_13": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,13], -1), dec13),
            "mse_14": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,14], -1), dec14)
        }
        
        eval_summary_hook = wtf.train.SummarySaverHook(
                                save_steps=1,
                                output_dir= "summary/train/" + MODEL_NAME + "/test",
                                scaffold=wtf.train.Scaffold(summary_op=wtf.summary.merge_all()))
        
        evaluation_hooks=[]
        evaluation_hooks.append(eval_summary_hook)
    
        estimator_spec = wtf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss,
            train_op=train_op,
            eval_metric_ops=eval_metric_ops,
            evaluation_hooks=evaluation_hooks
        )
        
        return estimator_spec

# %%
# t0,t1,t2,t3 -> t4 + LSTM

def model_fn(features,
             labels, # (N,11,H,W,1)
             mode,
             params):
    with wtf.device('/device:GPU:1'):
        labels = wtf.transpose(labels, [0, 2, 3, 1, 4])
        labels = wtf.squeeze(labels, [4]) # (N,H,W,5)
        
        # t4
        inputs_N3HW1 = features
        print(inputs_N3HW1)
        inputs_NHW3 = wtf.transpose(inputs_N3HW1, [0, 2, 3, 1, 4]) # (N,H,W,4,1)
        inp0 = wtf.squeeze(inputs_NHW3, [4]) # (N,H,W,4)
        print(inp0)
        enc0, pool0_1, pool0_3, pool0_4 = encoder_fn(inp0) # enc0 (N,6,7,1)
        print(enc0)
        dec0 = decoder_fn(enc0, pool0_1, pool0_3, pool0_4) # dec0 (N,H,W,1)
        print(dec0) # t3
        
        # t5
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp1 = wtf.concat([wtf.expand_dims(inp0[:,:,:,1], -1),
                               wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(inp0[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp1 = wtf.concat([wtf.expand_dims(inp0[:,:,:,1], -1),
                               wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(inp0[:,:,:,3], -1),
                               dec0], axis=3)
        print(inp1)
        enc1, pool1_1, pool1_3, pool1_4 = encoder_fn(inp1) # enc1 (N,6,7,1)
        print(enc1)
        dec1 = decoder_fn(enc1, pool1_1, pool1_3, pool1_4) # dec1 (N,H,W,1)
        print(dec1) # t6
        
        # t6
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp2 = wtf.concat([wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(inp0[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp2 = wtf.concat([wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(inp0[:,:,:,3], -1),
                               dec0,
                               dec1], axis=3)
        print(inp2)
        enc2, pool2_1, pool2_3, pool2_4 = encoder_fn(inp2) # enc2 (N,6,7,1)
        print(enc2)
        dec2 = decoder_fn(enc2, pool2_1, pool2_3, pool2_4) # dec2 (N,H,W,1)
        print(dec2) # t7
        
        # t7
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp3 = wtf.concat([wtf.expand_dims(inp0[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp3 = wtf.concat([wtf.expand_dims(inp0[:,:,:,3], -1),
                               dec0,
                               dec1,
                               dec2], axis=3)
        enc3, pool3_1, pool3_3, pool3_4 = encoder_fn(inp3) # enc3 (N,6,7,1)
        dec3 = decoder_fn(enc3, pool3_1, pool3_3, pool3_4) # dec3 (N,H,W,1)
        
        # t8
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp4 = wtf.concat([wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp4 = wtf.concat([dec0,
                               dec1,
                               dec2,
                               dec3], axis=3)
        enc4, pool4_1, pool4_3, pool4_4 = encoder_fn(inp4)
        dec4 = decoder_fn(enc4, pool4_1, pool4_3, pool4_4)
        
        # t9
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp5 = wtf.concat([wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp5 = wtf.concat([dec1,
                               dec2,
                               dec3,
                               dec4], axis=3)
        enc5, pool5_1, pool5_3, pool5_4 = encoder_fn(inp5)
        dec5 = decoder_fn(enc5, pool5_1, pool5_3, pool5_4)
        
        # t10
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp6 = wtf.concat([wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp6 = wtf.concat([dec2,
                               dec3,
                               dec4,
                               dec5], axis=3)
        enc6, pool6_1, pool6_3, pool6_4 = encoder_fn(inp6)
        dec6 = decoder_fn(enc6, pool6_1, pool6_3, pool6_4)
        
        # t11
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp7 = wtf.concat([wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp7 = wtf.concat([dec3,
                               dec4,
                               dec5,
                               dec6], axis=3)
        enc7, pool7_1, pool7_3, pool7_4 = encoder_fn(inp7)
        dec7 = decoder_fn(enc7, pool7_1, pool7_3, pool7_4)
        
        # t12
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp8 = wtf.concat([wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1),
                               wtf.expand_dims(labels[:,:,:,7], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp8 = wtf.concat([dec4,
                               dec5,
                               dec6,
                               dec7], axis=3)
        enc8, pool8_1, pool8_3, pool8_4 = encoder_fn(inp8)
        dec8 = decoder_fn(enc8, pool8_1, pool8_3, pool8_4)
        
        # t13
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp9 = wtf.concat([wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1),
                               wtf.expand_dims(labels[:,:,:,7], -1),
                               wtf.expand_dims(labels[:,:,:,8], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp9 = wtf.concat([dec5,
                               dec6,
                               dec7,
                               dec8], axis=3)
        enc9, pool9_1, pool9_3, pool9_4 = encoder_fn(inp9)
        dec9 = decoder_fn(enc9, pool9_1, pool9_3, pool9_4)
        
        # t14
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp10 = wtf.concat([wtf.expand_dims(labels[:,:,:,6], -1),
                                wtf.expand_dims(labels[:,:,:,7], -1),
                                wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp10 = wtf.concat([dec6,
                                dec7,
                                dec8,
                                dec9], axis=3)
        enc10, pool10_1, pool10_3, pool10_4 = encoder_fn(inp10)
        dec10 = decoder_fn(enc10, pool10_1, pool10_3, pool10_4)
        
        # t15
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp11 = wtf.concat([wtf.expand_dims(labels[:,:,:,7], -1),
                                wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1),
                                wtf.expand_dims(labels[:,:,:,10], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp11 = wtf.concat([dec7,
                                dec8,
                                dec9,
                                dec10], axis=3)
        enc11, pool11_1, pool11_3, pool11_4 = encoder_fn(inp11)
        dec11 = decoder_fn(enc11, pool11_1, pool11_3, pool11_4)
        
        # t16
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp12 = wtf.concat([wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1),
                                wtf.expand_dims(labels[:,:,:,10], -1),
                                wtf.expand_dims(labels[:,:,:,11], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp12 = wtf.concat([dec8,
                                dec9,
                                dec10,
                                dec11], axis=3)
        enc12, pool12_1, pool12_3, pool12_4 = encoder_fn(inp12)
        dec12 = decoder_fn(enc12, pool12_1, pool12_3, pool12_4)
        
        # t17
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp13 = wtf.concat([wtf.expand_dims(labels[:,:,:,9], -1),
                                wtf.expand_dims(labels[:,:,:,10], -1),
                                wtf.expand_dims(labels[:,:,:,11], -1),
                                wtf.expand_dims(labels[:,:,:,12], -1),], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp13 = wtf.concat([dec9,
                                dec10,
                                dec11,
                                dec12], axis=3)
        enc13, pool13_1, pool13_3, pool13_4 = encoder_fn(inp13)
        dec13 = decoder_fn(enc13, pool13_1, pool13_3, pool13_4)
        
        # Adds concatenated inputs and outputs to be displayed in TensorBoard
        disp00 = wtf.concat([wtf.expand_dims(inp0[:,:,:,0], -1),
                             wtf.expand_dims(inp0[:,:,:,1], -1),
                             wtf.expand_dims(inp0[:,:,:,2], -1),
                             wtf.expand_dims(inp0[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,0], -1),
                             dec0], axis=1)
        disp01 = wtf.concat([wtf.expand_dims(inp1[:,:,:,0], -1),
                             wtf.expand_dims(inp1[:,:,:,1], -1),
                             wtf.expand_dims(inp1[:,:,:,2], -1),
                             wtf.expand_dims(inp1[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,1], -1),
                             dec1], axis=1)
        disp02 = wtf.concat([wtf.expand_dims(inp2[:,:,:,0], -1),
                             wtf.expand_dims(inp2[:,:,:,1], -1),
                             wtf.expand_dims(inp2[:,:,:,2], -1),
                             wtf.expand_dims(inp2[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,2], -1),
                             dec2], axis=1)
        disp03 = wtf.concat([wtf.expand_dims(inp3[:,:,:,0], -1),
                             wtf.expand_dims(inp3[:,:,:,1], -1),
                             wtf.expand_dims(inp3[:,:,:,2], -1),
                             wtf.expand_dims(inp3[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,3], -1),
                             dec3], axis=1)
        disp04 = wtf.concat([wtf.expand_dims(inp4[:,:,:,0], -1),
                             wtf.expand_dims(inp4[:,:,:,1], -1),
                             wtf.expand_dims(inp4[:,:,:,2], -1),
                             wtf.expand_dims(inp4[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,4], -1),
                             dec4], axis=1)
        disp05 = wtf.concat([wtf.expand_dims(inp5[:,:,:,0], -1),
                             wtf.expand_dims(inp5[:,:,:,1], -1),
                             wtf.expand_dims(inp5[:,:,:,2], -1),
                             wtf.expand_dims(inp5[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,5], -1),
                             dec5], axis=1)
        disp06 = wtf.concat([wtf.expand_dims(inp6[:,:,:,0], -1),
                             wtf.expand_dims(inp6[:,:,:,1], -1),
                             wtf.expand_dims(inp6[:,:,:,2], -1),
                             wtf.expand_dims(inp6[:,:,:,3], -1),
                             wtf.expand_dims(inp6[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,6], -1),
                             dec6], axis=1)
        disp07 = wtf.concat([wtf.expand_dims(inp7[:,:,:,0], -1),
                             wtf.expand_dims(inp7[:,:,:,1], -1),
                             wtf.expand_dims(inp7[:,:,:,2], -1),
                             wtf.expand_dims(inp7[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,7], -1),
                             dec7], axis=1)
        disp08 = wtf.concat([wtf.expand_dims(inp8[:,:,:,0], -1),
                             wtf.expand_dims(inp8[:,:,:,1], -1),
                             wtf.expand_dims(inp8[:,:,:,2], -1),
                             wtf.expand_dims(inp8[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,8], -1),
                             dec8], axis=1)
        disp09 = wtf.concat([wtf.expand_dims(inp9[:,:,:,0], -1),
                             wtf.expand_dims(inp9[:,:,:,1], -1),
                             wtf.expand_dims(inp9[:,:,:,2], -1),
                             wtf.expand_dims(inp9[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,9], -1),
                             dec9], axis=1)
        disp10 = wtf.concat([wtf.expand_dims(inp10[:,:,:,0], -1),
                             wtf.expand_dims(inp10[:,:,:,1], -1),
                             wtf.expand_dims(inp10[:,:,:,2], -1),
                             wtf.expand_dims(inp10[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,10], -1),
                             dec10], axis=1)
        disp11 = wtf.concat([wtf.expand_dims(inp11[:,:,:,0], -1),
                             wtf.expand_dims(inp11[:,:,:,1], -1),
                             wtf.expand_dims(inp11[:,:,:,2], -1),
                             wtf.expand_dims(inp11[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,11], -1),
                             dec11], axis=1)
        disp12 = wtf.concat([wtf.expand_dims(inp12[:,:,:,0], -1),
                             wtf.expand_dims(inp12[:,:,:,1], -1),
                             wtf.expand_dims(inp12[:,:,:,2], -1),
                             wtf.expand_dims(inp12[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,12], -1),
                             dec12], axis=1)
        disp13 = wtf.concat([wtf.expand_dims(inp13[:,:,:,0], -1),
                             wtf.expand_dims(inp13[:,:,:,1], -1),
                             wtf.expand_dims(inp13[:,:,:,2], -1),
                             wtf.expand_dims(inp13[:,:,:,3], -1),
                             wtf.expand_dims(labels[:,:,:,13], -1),
                             dec13], axis=1)
#         disp14 = wtf.concat([wtf.expand_dims(inp14[:,:,:,0], -1),
#                              wtf.expand_dims(inp14[:,:,:,1], -1),
#                              wtf.expand_dims(inp14[:,:,:,2], -1),
#                              wtf.expand_dims(labels[:,:,:,14], -1),
#                              dec14], axis=1)
        disp = wtf.concat([disp00, disp01, disp02, disp03, disp04,
                           disp05, disp06, disp07, disp08, disp09,
                           disp10, disp11, disp12, disp13], axis=2)
        wtf.summary.image('concat', disp, max_outputs=200)
        
        loss = wtf.reduce_sum(16*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,0], -1), dec0)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,1], -1), dec1)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,2], -1), dec2)+
                              6*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,3], -1), dec3)+
                              6*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,4], -1), dec4)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,5], -1), dec5)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,6], -1), dec6)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,7], -1), dec7)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,8], -1), dec8)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,9], -1), dec9)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,10], -1), dec10)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,11], -1), dec11)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,12], -1), dec12)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,12], -1), dec13))
        
        outputs = dec13
        
        predictions = {'results': outputs}
    
        if mode == wtf.estimator.ModeKeys.PREDICT:
            export_outputs = {
                'predictions': wtf.estimator.export.PredictOutput(outputs)
            }
            return wtf.estimator.EstimatorSpec(
                mode=mode,
                predictions=outputs
            )
        
        global_step = wtf.train.get_global_step()
        lr = wtf.train.exponential_decay(params.learning_rate, global_step, 10000, 0.96, staircase=True)
        
        wtf.summary.scalar('learning_rate', lr)
#         wtf.summary.scalar('learning_rate', params.learning_rate)
        
        optimizer = wtf.train.AdamOptimizer(
#             learning_rate=params.learning_rate,
            learning_rate=lr,
            beta1=params.beta1,
            beta2=params.beta2
        )
    
        update_ops = wtf.get_collection(wtf.GraphKeys.UPDATE_OPS)
        with wtf.control_dependencies(update_ops):
            train_op = optimizer.minimize(
                loss=loss, global_step=wtf.train.get_global_step())
    
        eval_metric_ops = {
            "mse_0": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,0], -1), dec0),
            "mse_1": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,1], -1), dec1),
            "mse_2": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,2], -1), dec2),
            "mse_3": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,3], -1), dec3),
            "mse_4": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,4], -1), dec4),
            "mse_5": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,5], -1), dec5),
            "mse_6": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,6], -1), dec6),
            "mse_7": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,7], -1), dec7),
            "mse_8": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,8], -1), dec8),
            "mse_9": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,9], -1), dec9),
            "mse_10": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,10], -1), dec10),
            "mse_11": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,11], -1), dec11),
            "mse_12": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,12], -1), dec12),
            "mse_13": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,13], -1), dec13)
        }
        
        eval_summary_hook = wtf.train.SummarySaverHook(
                                save_steps=1,
                                output_dir= "summary/train/" + MODEL_NAME + "/eval",
                                scaffold=wtf.train.Scaffold(summary_op=wtf.summary.merge_all()))
        
        evaluation_hooks=[]
        evaluation_hooks.append(eval_summary_hook)
    
        estimator_spec = wtf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss,
            train_op=train_op,
            eval_metric_ops=eval_metric_ops,
            evaluation_hooks=evaluation_hooks
        )
        
        return estimator_spec

# %%
# t0,t1,t2,t3,t4 -> t5 + LSTM

def model_fn(features,
             labels, # (N,11,H,W,1)
             mode,
             params):
    with wtf.device('/device:GPU:1'):
        labels = wtf.transpose(labels, [0, 2, 3, 1, 4])
        labels = wtf.squeeze(labels, [4]) # (N,H,W,5)
        
        # t0, t1, t2, t3, t4  -> t5
        inputs_N3HW1 = features
        print(inputs_N3HW1)
        inputs_NHW3 = wtf.transpose(inputs_N3HW1, [0, 2, 3, 1, 4]) # (N,H,W,5,1)
        inp0 = wtf.squeeze(inputs_NHW3, [4]) # (N,H,W,5)
        print(inp0)
        enc0, pool0_1, pool0_3, pool0_4 = encoder_fn(inp0) # enc0 (N,6,7,1)
        print(enc0)
        dec0 = decoder_fn(enc0, pool0_1, pool0_3, pool0_4) # dec0 (N,H,W,1)
        print(dec0) # t3
        
        # t1, t2, t3, t4, t5  -> t6
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp1 = wtf.concat([wtf.expand_dims(inp0[:,:,:,1], -1),
                               wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(inp0[:,:,:,3], -1),
                               wtf.expand_dims(inp0[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp1 = wtf.concat([wtf.expand_dims(inp0[:,:,:,1], -1),
                               wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(inp0[:,:,:,3], -1),
                               wtf.expand_dims(inp0[:,:,:,4], -1),
                               dec0], axis=3)
        print(inp1)
        enc1, pool1_1, pool1_3, pool1_4 = encoder_fn(inp1) # enc1 (N,6,7,1)
        print(enc1)
        dec1 = decoder_fn(enc1, pool1_1, pool1_3, pool1_4) # dec1 (N,H,W,1)
        print(dec1) # t6
        
        # t2, t3, t4, t5, t6  -> t7
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp2 = wtf.concat([wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(inp0[:,:,:,3], -1),
                               wtf.expand_dims(inp0[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp2 = wtf.concat([wtf.expand_dims(inp0[:,:,:,2], -1),
                               wtf.expand_dims(inp0[:,:,:,3], -1),
                               wtf.expand_dims(inp0[:,:,:,4], -1),
                               dec0,
                               dec1], axis=3)
        print(inp2)
        enc2, pool2_1, pool2_3, pool2_4 = encoder_fn(inp2) # enc2 (N,6,7,1)
        print(enc2)
        dec2 = decoder_fn(enc2, pool2_1, pool2_3, pool2_4) # dec2 (N,H,W,1)
        print(dec2) # t7
        
        # t3, t4, t5, t6, t7  -> t8
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp3 = wtf.concat([wtf.expand_dims(inp0[:,:,:,3], -1),
                               wtf.expand_dims(inp0[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp3 = wtf.concat([wtf.expand_dims(inp0[:,:,:,3], -1),
                               wtf.expand_dims(inp0[:,:,:,4], -1),
                               dec0,
                               dec1,
                               dec2], axis=3)
        enc3, pool3_1, pool3_3, pool3_4 = encoder_fn(inp3) # enc3 (N,6,7,1)
        dec3 = decoder_fn(enc3, pool3_1, pool3_3, pool3_4) # dec3 (N,H,W,1)
        
        # t4, t5, t6, t7, t8  -> t9
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp4 = wtf.concat([wtf.expand_dims(inp0[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp4 = wtf.concat([wtf.expand_dims(inp0[:,:,:,4], -1),
                               dec0,
                               dec1,
                               dec2,
                               dec3], axis=3)
        enc4, pool4_1, pool4_3, pool4_4 = encoder_fn(inp4)
        dec4 = decoder_fn(enc4, pool4_1, pool4_3, pool4_4)
        
        # t5, t6, t7, t8, t9 -> t10
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp5 = wtf.concat([wtf.expand_dims(labels[:,:,:,0], -1),
                               wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp5 = wtf.concat([dec0,
                               dec1,
                               dec2,
                               dec3,
                               dec4], axis=3)
        enc5, pool5_1, pool5_3, pool5_4 = encoder_fn(inp5)
        dec5 = decoder_fn(enc5, pool5_1, pool5_3, pool5_4)
        
        # t6, t7, t8, t9,t10 -> t11
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp6 = wtf.concat([wtf.expand_dims(labels[:,:,:,1], -1),
                               wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp6 = wtf.concat([dec1,
                               dec2,
                               dec3,
                               dec4,
                               dec5], axis=3)
        enc6, pool6_1, pool6_3, pool6_4 = encoder_fn(inp6)
        dec6 = decoder_fn(enc6, pool6_1, pool6_3, pool6_4)
        
        # t7, t8, t9,t10,t11 -> t12
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp7 = wtf.concat([wtf.expand_dims(labels[:,:,:,2], -1),
                               wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp7 = wtf.concat([dec2,
                               dec3,
                               dec4,
                               dec5,
                               dec6], axis=3)
        enc7, pool7_1, pool7_3, pool7_4 = encoder_fn(inp7)
        dec7 = decoder_fn(enc7, pool7_1, pool7_3, pool7_4)
        
        # t8, t9,t10,t11,t12 -> t13
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp8 = wtf.concat([wtf.expand_dims(labels[:,:,:,3], -1),
                               wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1),
                               wtf.expand_dims(labels[:,:,:,7], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp8 = wtf.concat([dec3,
                               dec4,
                               dec5,
                               dec6,
                               dec7], axis=3)
        enc8, pool8_1, pool8_3, pool8_4 = encoder_fn(inp8)
        dec8 = decoder_fn(enc8, pool8_1, pool8_3, pool8_4)
        
        # t9, t10,t11,t12,t13 -> t14
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp9 = wtf.concat([wtf.expand_dims(labels[:,:,:,4], -1),
                               wtf.expand_dims(labels[:,:,:,5], -1),
                               wtf.expand_dims(labels[:,:,:,6], -1),
                               wtf.expand_dims(labels[:,:,:,7], -1),
                               wtf.expand_dims(labels[:,:,:,8], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp9 = wtf.concat([dec4,
                               dec5,
                               dec6,
                               dec7,
                               dec8], axis=3)
        enc9, pool9_1, pool9_3, pool9_4 = encoder_fn(inp9)
        dec9 = decoder_fn(enc9, pool9_1, pool9_3, pool9_4)
        
        # t10,t11,t12,t13,t14 -> t15
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp10 = wtf.concat([wtf.expand_dims(labels[:,:,:,5], -1),
                                wtf.expand_dims(labels[:,:,:,6], -1),
                                wtf.expand_dims(labels[:,:,:,7], -1),
                                wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp10 = wtf.concat([dec5,
                                dec6,
                                dec7,
                                dec8,
                                dec9], axis=3)
        enc10, pool10_1, pool10_3, pool10_4 = encoder_fn(inp10)
        dec10 = decoder_fn(enc10, pool10_1, pool10_3, pool10_4)
        
        # t11,t12,t13,t14,t15 -> t16
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp11 = wtf.concat([wtf.expand_dims(labels[:,:,:,6], -1),
                                wtf.expand_dims(labels[:,:,:,7], -1),
                                wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1),
                                wtf.expand_dims(labels[:,:,:,10], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp11 = wtf.concat([dec6,
                                dec7,
                                dec8,
                                dec9,
                                dec10], axis=3)
        enc11, pool11_1, pool11_3, pool11_4 = encoder_fn(inp11)
        dec11 = decoder_fn(enc11, pool11_1, pool11_3, pool11_4)
        
        # t12,t13,t14,t15,t16 -> t17
        if mode == wtf.estimator.ModeKeys.TRAIN:
            inp12 = wtf.concat([wtf.expand_dims(labels[:,:,:,7], -1),
                                wtf.expand_dims(labels[:,:,:,8], -1),
                                wtf.expand_dims(labels[:,:,:,9], -1),
                                wtf.expand_dims(labels[:,:,:,10], -1),
                                wtf.expand_dims(labels[:,:,:,11], -1)], axis=3)
        elif mode == wtf.estimator.ModeKeys.EVAL:
            inp12 = wtf.concat([dec7,
                                dec8,
                                dec9,
                                dec10,
                                dec11], axis=3)
        enc12, pool12_1, pool12_3, pool12_4 = encoder_fn(inp12)
        dec12 = decoder_fn(enc12, pool12_1, pool12_3, pool12_4)
        
        # Adds concatenated inputs and outputs to be displayed in TensorBoard
        disp00 = wtf.concat([wtf.expand_dims(inp0[:,:,:,0], -1),
                             wtf.expand_dims(inp0[:,:,:,1], -1),
                             wtf.expand_dims(inp0[:,:,:,2], -1),
                             wtf.expand_dims(inp0[:,:,:,3], -1),
                             wtf.expand_dims(inp0[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,0], -1),
                             dec0], axis=1)
        disp01 = wtf.concat([wtf.expand_dims(inp1[:,:,:,0], -1),
                             wtf.expand_dims(inp1[:,:,:,1], -1),
                             wtf.expand_dims(inp1[:,:,:,2], -1),
                             wtf.expand_dims(inp1[:,:,:,3], -1),
                             wtf.expand_dims(inp1[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,1], -1),
                             dec1], axis=1)
        disp02 = wtf.concat([wtf.expand_dims(inp2[:,:,:,0], -1),
                             wtf.expand_dims(inp2[:,:,:,1], -1),
                             wtf.expand_dims(inp2[:,:,:,2], -1),
                             wtf.expand_dims(inp2[:,:,:,3], -1),
                             wtf.expand_dims(inp2[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,2], -1),
                             dec2], axis=1)
        disp03 = wtf.concat([wtf.expand_dims(inp3[:,:,:,0], -1),
                             wtf.expand_dims(inp3[:,:,:,1], -1),
                             wtf.expand_dims(inp3[:,:,:,2], -1),
                             wtf.expand_dims(inp3[:,:,:,3], -1),
                             wtf.expand_dims(inp3[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,3], -1),
                             dec3], axis=1)
        disp04 = wtf.concat([wtf.expand_dims(inp4[:,:,:,0], -1),
                             wtf.expand_dims(inp4[:,:,:,1], -1),
                             wtf.expand_dims(inp4[:,:,:,2], -1),
                             wtf.expand_dims(inp4[:,:,:,3], -1),
                             wtf.expand_dims(inp4[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,4], -1),
                             dec4], axis=1)
        disp05 = wtf.concat([wtf.expand_dims(inp5[:,:,:,0], -1),
                             wtf.expand_dims(inp5[:,:,:,1], -1),
                             wtf.expand_dims(inp5[:,:,:,2], -1),
                             wtf.expand_dims(inp5[:,:,:,3], -1),
                             wtf.expand_dims(inp5[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,5], -1),
                             dec5], axis=1)
        disp06 = wtf.concat([wtf.expand_dims(inp6[:,:,:,0], -1),
                             wtf.expand_dims(inp6[:,:,:,1], -1),
                             wtf.expand_dims(inp6[:,:,:,2], -1),
                             wtf.expand_dims(inp6[:,:,:,3], -1),
                             wtf.expand_dims(inp6[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,6], -1),
                             dec6], axis=1)
        disp07 = wtf.concat([wtf.expand_dims(inp7[:,:,:,0], -1),
                             wtf.expand_dims(inp7[:,:,:,1], -1),
                             wtf.expand_dims(inp7[:,:,:,2], -1),
                             wtf.expand_dims(inp7[:,:,:,3], -1),
                             wtf.expand_dims(inp7[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,7], -1),
                             dec7], axis=1)
        disp08 = wtf.concat([wtf.expand_dims(inp8[:,:,:,0], -1),
                             wtf.expand_dims(inp8[:,:,:,1], -1),
                             wtf.expand_dims(inp8[:,:,:,2], -1),
                             wtf.expand_dims(inp8[:,:,:,3], -1),
                             wtf.expand_dims(inp8[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,8], -1),
                             dec8], axis=1)
        disp09 = wtf.concat([wtf.expand_dims(inp9[:,:,:,0], -1),
                             wtf.expand_dims(inp9[:,:,:,1], -1),
                             wtf.expand_dims(inp9[:,:,:,2], -1),
                             wtf.expand_dims(inp9[:,:,:,3], -1),
                             wtf.expand_dims(inp9[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,9], -1),
                             dec9], axis=1)
        disp10 = wtf.concat([wtf.expand_dims(inp10[:,:,:,0], -1),
                             wtf.expand_dims(inp10[:,:,:,1], -1),
                             wtf.expand_dims(inp10[:,:,:,2], -1),
                             wtf.expand_dims(inp10[:,:,:,3], -1),
                             wtf.expand_dims(inp10[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,10], -1),
                             dec10], axis=1)
        disp11 = wtf.concat([wtf.expand_dims(inp11[:,:,:,0], -1),
                             wtf.expand_dims(inp11[:,:,:,1], -1),
                             wtf.expand_dims(inp11[:,:,:,2], -1),
                             wtf.expand_dims(inp11[:,:,:,3], -1),
                             wtf.expand_dims(inp11[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,11], -1),
                             dec11], axis=1)
        disp12 = wtf.concat([wtf.expand_dims(inp12[:,:,:,0], -1),
                             wtf.expand_dims(inp12[:,:,:,1], -1),
                             wtf.expand_dims(inp12[:,:,:,2], -1),
                             wtf.expand_dims(inp12[:,:,:,3], -1),
                             wtf.expand_dims(inp12[:,:,:,4], -1),
                             wtf.expand_dims(labels[:,:,:,12], -1),
                             dec12], axis=1)
        disp = wtf.concat([disp00, disp01, disp02, disp03, disp04,
                           disp05, disp06, disp07, disp08, disp09,
                           disp10, disp11, disp12], axis=2)
        wtf.summary.image('concat', disp, max_outputs=200)
        
        loss = wtf.reduce_sum(12*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,0], -1), dec0)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,1], -1), dec1)+
                              8*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,2], -1), dec2)+
                              6*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,3], -1), dec3)+
                              6*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,4], -1), dec4)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,5], -1), dec5)+
                              4*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,6], -1), dec6)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,7], -1), dec7)+
                              2*wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,8], -1), dec8)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,9], -1), dec9)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,10], -1), dec10)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,11], -1), dec11)+
                              wtf.losses.mean_squared_error(wtf.expand_dims(labels[:,:,:,12], -1), dec12))
        
        outputs = dec12
        
        predictions = {'results': outputs}
    
        if mode == wtf.estimator.ModeKeys.PREDICT:
            export_outputs = {
                'predictions': wtf.estimator.export.PredictOutput(outputs)
            }
            return wtf.estimator.EstimatorSpec(
                mode=mode,
                predictions=outputs
            )
        
        global_step = wtf.train.get_global_step()
        lr = wtf.train.exponential_decay(params.learning_rate, global_step, 10000, 0.96, staircase=True)
        
        wtf.summary.scalar('learning_rate', lr)
#         wtf.summary.scalar('learning_rate', params.learning_rate)
        
        optimizer = wtf.train.AdamOptimizer(
#             learning_rate=params.learning_rate,
            learning_rate=lr,
            beta1=params.beta1,
            beta2=params.beta2
        )
    
        update_ops = wtf.get_collection(wtf.GraphKeys.UPDATE_OPS)
        with wtf.control_dependencies(update_ops):
            train_op = optimizer.minimize(
                loss=loss, global_step=wtf.train.get_global_step())
    
        eval_metric_ops = {
            "mse_0": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,0], -1), dec0),
            "mse_1": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,1], -1), dec1),
            "mse_2": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,2], -1), dec2),
            "mse_3": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,3], -1), dec3),
            "mse_4": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,4], -1), dec4),
            "mse_5": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,5], -1), dec5),
            "mse_6": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,6], -1), dec6),
            "mse_7": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,7], -1), dec7),
            "mse_8": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,8], -1), dec8),
            "mse_9": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,9], -1), dec9),
            "mse_10": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,10], -1), dec10),
            "mse_11": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,11], -1), dec11),
            "mse_12": wtf.metrics.mean_squared_error(wtf.expand_dims(labels[:,:,:,12], -1), dec12)
        }
        
        eval_summary_hook = wtf.train.SummarySaverHook(
                                save_steps=1,
                                output_dir= "summary/train/" + MODEL_NAME + "/test",
                                scaffold=wtf.train.Scaffold(summary_op=wtf.summary.merge_all()))
        
        evaluation_hooks=[]
        evaluation_hooks.append(eval_summary_hook)
    
        estimator_spec = wtf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss,
            train_op=train_op,
            eval_metric_ops=eval_metric_ops,
            evaluation_hooks=evaluation_hooks
        )
        
        return estimator_spec

# %%
def main(_):
    os.environ['CUDA_VISIBLE_DEVICES'] = '0'
    
    wtf.logging.set_verbosity(wtf.logging.INFO)

    hparams = wtf.contrib.training.HParams(
        learning_rate=0.0001,
        beta1=0.9,
        beta2=0.999
    )
    
    session_config = wtf.ConfigProto()
    session_config.gpu_options.allow_growth = True
    session_config.allow_soft_placement = True
    
    run_config = wtf.estimator.RunConfig(
        log_step_count_steps=10,
        save_summary_steps=10,
        tf_random_seed=19830610,
        model_dir=os.path.join('summary', 'train', MODEL_NAME),
        session_config=session_config
    )
    
    estimator = wtf.estimator.Estimator(
        model_fn=model_fn, params=hparams, config=run_config)
    
    train_dataset = du.create_dataset_g7('train', train_data)
#     train_dataset = du.create_dataset_g7_n('train', train_data, 5)
#     train_dataset = du.create_dataset_g7_adaproon('train', train_data, 3)
    train_dataset = train_dataset.shuffle(512)
    train_dataset = train_dataset.batch(BATCH_SIZE)
    train_dataset = train_dataset.repeat(EPOCHS)
    
    val_dataset = du.create_dataset_g7('val', val_data)
#     val_dataset = du.create_dataset_g7_n('val', val_data, 5)
#     val_dataset = du.create_dataset_g7_adaproon('val', val_data, 3)
    val_dataset = val_dataset.batch(BATCH_SIZE)
    val_dataset = val_dataset.repeat(1)
    
    test_dataset = du.create_dataset_g7('test', test_data)
#     test_dataset = du.create_dataset_g7_n('test', test_data, 5)
#     test_dataset = du.create_dataset_g7_adaproon('test', test_data, 3)
    test_dataset = test_dataset.batch(BATCH_SIZE)
    test_dataset = test_dataset.repeat(1)
    
    def train_input_fn():
        train_iterator = train_dataset.make_one_shot_iterator()
        features, labels = train_iterator.get_next()
        return features, labels
    
    def val_input_fn():
        val_iterator = val_dataset.make_one_shot_iterator()
        features, labels = val_iterator.get_next()
        return features, labels
    
    def test_input_fn():
        test_iterator = test_dataset.make_one_shot_iterator()
        features, labels = test_iterator.get_next()
        return features, labels
    
#     estimator.train(input_fn=train_input_fn, max_steps=None)
#     estimator.evaluate(input_fn=val_input_fn)
    estimator.evaluate(input_fn=test_input_fn)

# %%
if __name__ == '__main__':
    wtf.app.run()
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'summary/train/game7-005-noreuse', '_tf_random_seed': 19830610, '_save_summary_steps': 10, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
#   allow_growth: true
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 10, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8a448dc978>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# Tensor("IteratorGetNext:0", shape=(?, 3, 192, 224, 1), dtype=float32, device=/device:CPU:0)
# Tensor("Squeeze_1:0", shape=(?, 192, 224, 3), dtype=float32, device=/device:GPU:1)
# Tensor("v00/dropout/Identity:0", shape=(?, 6, 7, 1), dtype=float32, device=/device:GPU:1)
# ...
